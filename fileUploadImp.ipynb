# %% [markdown]
# <a href="https://colab.research.google.com/github/SandeepKonduruFeb12/aiml/blob/master/fileUploadImp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Step 1: Enable the Google Drive API and Get Credentials
#
# 1.  Go to the [Google Cloud Console](https://console.cloud.google.com/).
# 2.  Create a new project or select an existing one.
# 3.  Navigate to "APIs & Services" > "Library".
# 4.  Search for "Google Drive API" and enable it.
# 5.  Go to "APIs & Services" > "Credentials".
# 6.  Click "Create Credentials" > "OAuth client ID".
# 7.  Select "Desktop app" as the application type and give it a name (e.g., "Drive Uploader").
# 8.  Click "Create", then "Download JSON" to get your `client_secret.json` file. Rename it to `credentials.json` and upload this file to your Colab environment (e.g., via the file explorer icon on the left panel).

# %% [markdown]
# ### Simpler Method: Mount Google Drive in Colab
#
# This method is recommended for Colab users as it leverages Colab's built-in integration with Google Drive. You will be prompted to authorize Colab to access your Google Drive.

# %%
from google.colab import drive
import shutil
import os

# Mount Google Drive

drive.mount('/content/drive')

print("Google Drive mounted successfully!")

# Define the local file you want to copy (using the one created earlier)
local_file_path = '/SandeepKonduruDec2025.pdf'

# Define the destination path in your Google Drive
# This will copy it to the root of your Google Drive.
# You can specify a folder like '/content/drive/My Drive/MyFolder/my_local_file.txt'
drive_destination_path = '/content/drive/My Drive/' + os.path.basename(local_file_path)

# Copy the file from local Colab environment to Google Drive
try:
    shutil.copy(local_file_path, drive_destination_path)
    print(f"Successfully copied '{local_file_path}' to Google Drive at '{drive_destination_path}'")
except FileNotFoundError:
    print(f"Error: Local file '{local_file_path}' not found.")
except Exception as e:
    print(f"An error occurred while copying the file: {e}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Google Drive mounted successfully!
# Successfully copied '/SandeepKonduruDec2025.pdf' to Google Drive at '/content/drive/My Drive/SandeepKonduruDec2025.pdf'
